# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Ex - 2

# %%
drug_df = pd.read_csv('Data/drug.csv')
drug_df
# Out:
#                  urlDrugName  rating           effectiveness  \
# 0     2202         enalapril       4        Highly Effective
# 1     3117  ortho-tri-cyclen       1        Highly Effective
# 2     1146           ponstel      10        Highly Effective
# 3     3947          prilosec       3    Marginally Effective
# 4     1951            lyrica       2    Marginally Effective
# ...    ...               ...     ...                     ...
# 3102  1039           vyvanse      10        Highly Effective
# 3103  3281            zoloft       1             Ineffective
# 3104  1664           climara       2    Marginally Effective
# 3105  2621         trileptal       8  Considerably Effective
# 3106  2748          micardis       4    Moderately Effective
#
#                         sideEffects                               condition  \
# 0                 Mild Side Effects  management of congestive heart failure
# 1               Severe Side Effects                        birth prevention
# ...

# %% [markdown]
# # Ex - 3

# %%
feedback_df = pd.read_table('Data/feedback.txt', names = ['Reviews'])
feedback_df
# Out:
#                                               Reviews
# 0              The food for our event was delicious .
# 1    The food in the lounge was great and very fre...
# 2    As far as food, walk a few blocks toward Mich...
# 3    The Palm resturant in the hotel had some spec...
# 4    Took the charge of the minibar which we had u...
# 5    We never ate anything onsite so I can't vouch...
# 6    The Lobby bar does not serve food very late a...
# 7    In any case, I had allotted approximately $15...
# 8    But the presentation was awesome and the food...
# 9    The food was delicious and the view was fabul...
# 10   For self catering types, Bockwinkels is a wel...
# 11   Room service was extortionate though, very ve...
# 12   We also did the chicago food tasting tour whi...
# 13   So if you move around bottles in the fridge s...
# 14   We passed on the restaurants simply because t...
# 15   Also don't forget to go the &quot The River N...
# ...

# %%
feedback_df['Column_Id'] = pd.Series(range(0, 51))
feedback_df
# Out:
#                                               Reviews  Column_Id
# 0              The food for our event was delicious .          0
# 1    The food in the lounge was great and very fre...          1
# 2    As far as food, walk a few blocks toward Mich...          2
# 3    The Palm resturant in the hotel had some spec...          3
# 4    Took the charge of the minibar which we had u...          4
# 5    We never ate anything onsite so I can't vouch...          5
# 6    The Lobby bar does not serve food very late a...          6
# 7    In any case, I had allotted approximately $15...          7
# 8    But the presentation was awesome and the food...          8
# 9    The food was delicious and the view was fabul...          9
# 10   For self catering types, Bockwinkels is a wel...         10
# 11   Room service was extortionate though, very ve...         11
# 12   We also did the chicago food tasting tour whi...         12
# ...

# %% [markdown]
# # Ex - 4

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('Data/breakfast_menu.xml')
root = tree.getroot()
data = []
for food in root.findall("food"):
    item = {
        "name": food.find("name").text,
        "price": food.find("price").text,
        "description": food.find("description").text,
        "calories": int(food.find("calories").text)
    }
    data.append(item)

df = pd.DataFrame(data)

df
# Out:
#                           name  price  \
# 0              Belgian Waffles  $5.95
# 1   Strawberry Belgian Waffles  $7.95
# 2  Berry-Berry Belgian Waffles  $8.95
# 3                 French Toast  $4.50
# 4          Homestyle Breakfast  $6.95
#
#                                          description  calories
# 0   Two of our famous Belgian Waffles with plenty...       650
# 1   Light Belgian waffles covered with strawberri...       900
# 2   Light Belgian waffles covered with an assortm...       900
# 3   Thick slices made from our homemade sourdough...       600
# 4   Two eggs, bacon or sausage, toast, and our ev...       950

# %%
df.to_csv('Data/breakfast_menu.csv')

# %% [markdown]
# # Ex - 5

# %%
# drug_df from Ex-2

# %%
drug_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3107 entries, 0 to 3106
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0                      3107 non-null   int64
#  1   urlDrugName        3107 non-null   object
#  2   rating             3107 non-null   int64
#  3   effectiveness      3107 non-null   object
#  4   sideEffects        3107 non-null   object
#  5   condition          3106 non-null   object
#  6   benefitsReview     3089 non-null   object
#  7   sideEffectsReview  3032 non-null   object
#  8   commentsReview     3095 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 218.6+ KB

# %%
drug_df.shape[0]
# Out:
# 3107

# %%
drug_df.isna().sum()
# Out:
#                       0
# urlDrugName           0
# rating                0
# effectiveness         0
# sideEffects           0
# condition             1
# benefitsReview       18
# sideEffectsReview    75
# commentsReview       12
# dtype: int64

# %%
drug_df['condition'].isna().sum()
# Out:
# 1

# %%
drug_df['condition'] = drug_df['condition'].fillna('No condition specified')
drug_df['condition'].isna().sum()
# Out:
# 0

# %%
drug_df[drug_df['effectiveness'] == 'Highly Effective']
# Out:
#                  urlDrugName  rating     effectiveness          sideEffects  \
# 0     2202         enalapril       4  Highly Effective    Mild Side Effects
# 1     3117  ortho-tri-cyclen       1  Highly Effective  Severe Side Effects
# 2     1146           ponstel      10  Highly Effective      No Side Effects
# 6     1043           vyvanse       9  Highly Effective    Mild Side Effects
# 8     1591             xanax      10  Highly Effective      No Side Effects
# ...    ...               ...     ...               ...                  ...
# 3091  2058           prempro       9  Highly Effective    Mild Side Effects
# 3092  2176            zyrtec      10  Highly Effective    Mild Side Effects
# 3094   539         trazodone      10  Highly Effective      No Side Effects
# 3098  2148            zyrtec      10  Highly Effective      No Side Effects
# 3102  1039           vyvanse      10  Highly Effective    Mild Side Effects
#
#                                       condition  \
# ...

# %%
drug_df[drug_df['effectiveness'] == 'Considerably Effective']
# Out:
#             urlDrugName  rating           effectiveness  \
# 7     2715       elavil      10  Considerably Effective
# 10     458       flagyl       7  Considerably Effective
# 12     959      sarafem       8  Considerably Effective
# 13     928      latisse       9  Considerably Effective
# 14    2643       aldara       4  Considerably Effective
# ...    ...          ...     ...                     ...
# 3097  2235      allegra       8  Considerably Effective
# 3099  2613  adderall-xr       8  Considerably Effective
# 3100   709     accutane       7  Considerably Effective
# 3101  3485     diazepam       8  Considerably Effective
# 3105  2621    trileptal       8  Considerably Effective
#
#                 sideEffects                          condition  \
# 7           No Side Effects                         depression
# 10    Moderate Side Effects                bacterial vaginosis
# 12        Mild Side Effects                         depression
# ...

# %%
side_effect_mapping = {
    'Extremely Severe Side Effects': 5,
    'Severe Side Effects': 4,
    'Moderate Side Effects': 3,
    'Mild Side Effects': 2,
    'No Side Effects': 1
}

drug_df['Side_Effect_Rating'] = drug_df['sideEffects'].map(side_effect_mapping)
drug_df
# Out:
#                  urlDrugName  rating           effectiveness  \
# 0     2202         enalapril       4        Highly Effective
# 1     3117  ortho-tri-cyclen       1        Highly Effective
# 2     1146           ponstel      10        Highly Effective
# 3     3947          prilosec       3    Marginally Effective
# 4     1951            lyrica       2    Marginally Effective
# ...    ...               ...     ...                     ...
# 3102  1039           vyvanse      10        Highly Effective
# 3103  3281            zoloft       1             Ineffective
# 3104  1664           climara       2    Marginally Effective
# 3105  2621         trileptal       8  Considerably Effective
# 3106  2748          micardis       4    Moderately Effective
#
#                         sideEffects                               condition  \
# 0                 Mild Side Effects  management of congestive heart failure
# 1               Severe Side Effects                        birth prevention
# ...

# %% [markdown]
# # Ex - 6

# %%
dataAir = pd.read_csv('Data/AirPassengers.csv')
first_half_df = dataAir.iloc[:,:6]
second_half_df = dataAir.iloc[:,6:]

# %%
first_half_df.head()
# Out:
#    Jan    Feb    Mar  Apr  May    Jun
# 0  112  118.0  132.0  129  121  135.0
# 1  115    NaN  141.0  135  125  149.0
# 2  145  150.0  178.0  163  172    NaN
# 3  171  180.0  193.0  181  183  218.0
# 4  196  196.0  236.0  235  229  243.0

# %%
second_half_df.head()
# Out:
#    Jul    Aug  Sep    Oct    Nov    Dec
# 0  148  148.0  136  119.0  104.0    NaN
# 1  170  170.0  158  133.0  114.0  140.0
# 2  199  199.0  184  162.0  146.0  166.0
# 3  230    NaN  209  191.0  172.0  194.0
# 4  264  272.0  237  211.0  180.0  201.0

# %%
air_df = first_half_df.merge(second_half_df, left_index=True, right_index=True, how='inner')
air_df
# Out:
#     Jan    Feb    Mar  Apr  May    Jun  Jul    Aug  Sep    Oct    Nov    Dec
# 0   112  118.0  132.0  129  121  135.0  148  148.0  136  119.0  104.0    NaN
# 1   115    NaN  141.0  135  125  149.0  170  170.0  158  133.0  114.0  140.0
# 2   145  150.0  178.0  163  172    NaN  199  199.0  184  162.0  146.0  166.0
# 3   171  180.0  193.0  181  183  218.0  230    NaN  209  191.0  172.0  194.0
# 4   196  196.0  236.0  235  229  243.0  264  272.0  237  211.0  180.0  201.0
# 5   204  188.0  235.0  227  234  264.0  302  293.0  259    NaN  203.0  229.0
# 6   242    NaN  267.0  269  270  315.0  364  347.0  312  274.0  237.0  278.0
# 7   284  277.0  317.0  313  318  374.0  413  405.0  355  306.0  271.0  306.0
# 8   315  301.0  356.0  348  355  422.0  465  467.0  404  347.0  305.0  336.0
# 9   340  318.0  362.0  348  363  435.0  491  505.0  404  359.0    NaN  337.0
# 10  360  342.0    NaN  396  420  472.0  548  559.0  463  407.0  362.0  405.0
# ...

# %%
air_df.isna().sum()
# Out:
# Jan    0
# Feb    2
# Mar    1
# Apr    0
# May    0
# Jun    1
# Jul    0
# Aug    1
# Sep    0
# Oct    1
# Nov    1
# Dec    1
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
df = air_df.loc[:,["Feb"]]
df[df.isna().any(axis=1)].index.tolist()
# Out:
# [1, 6]

# %%
air_df['Feb'] = air_df['Feb'].fillna(air_df['Feb'].median())
air_df['Mar'] = air_df['Mar'].fillna(air_df['Mar'].median())
air_df['Jun'] = air_df['Jun'].fillna(air_df['Jun'].median())
air_df['Aug'] = air_df['Aug'].fillna(air_df['Aug'].median())
air_df['Oct'] = air_df['Oct'].fillna(air_df['Oct'].median())
air_df['Nov'] = air_df['Nov'].fillna(air_df['Nov'].median())
air_df['Dec'] = air_df['Dec'].fillna(air_df['Dec'].median())
air_df
# Out:
#     Jan    Feb    Mar  Apr  May    Jun  Jul    Aug  Sep    Oct    Nov    Dec
# 0   112  118.0  132.0  129  121  135.0  148  148.0  136  119.0  104.0  278.0
# 1   115  236.5  141.0  135  125  149.0  170  170.0  158  133.0  114.0  140.0
# 2   145  150.0  178.0  163  172  315.0  199  199.0  184  162.0  146.0  166.0
# 3   171  180.0  193.0  181  183  218.0  230  347.0  209  191.0  172.0  194.0
# 4   196  196.0  236.0  235  229  243.0  264  272.0  237  211.0  180.0  201.0
# 5   204  188.0  235.0  227  234  264.0  302  293.0  259  274.0  203.0  229.0
# 6   242  236.5  267.0  269  270  315.0  364  347.0  312  274.0  237.0  278.0
# 7   284  277.0  317.0  313  318  374.0  413  405.0  355  306.0  271.0  306.0
# 8   315  301.0  356.0  348  355  422.0  465  467.0  404  347.0  305.0  336.0
# 9   340  318.0  362.0  348  363  435.0  491  505.0  404  359.0  203.0  337.0
# 10  360  342.0  236.0  396  420  472.0  548  559.0  463  407.0  362.0  405.0
# ...

# %%
air_df.isna().sum()
# Out:
# Jan    0
# Feb    0
# Mar    0
# Apr    0
# May    0
# Jun    0
# Jul    0
# Aug    0
# Sep    0
# Oct    0
# Nov    0
# Dec    0
# dtype: int64

# %%
air_df['Year'] = pd.Series(range(1949, 1961))
air_df
# Out:
#     Jan    Feb    Mar  Apr  May    Jun  Jul    Aug  Sep    Oct    Nov    Dec  \
# 0   112  118.0  132.0  129  121  135.0  148  148.0  136  119.0  104.0  278.0
# 1   115  236.5  141.0  135  125  149.0  170  170.0  158  133.0  114.0  140.0
# 2   145  150.0  178.0  163  172  315.0  199  199.0  184  162.0  146.0  166.0
# 3   171  180.0  193.0  181  183  218.0  230  347.0  209  191.0  172.0  194.0
# 4   196  196.0  236.0  235  229  243.0  264  272.0  237  211.0  180.0  201.0
# 5   204  188.0  235.0  227  234  264.0  302  293.0  259  274.0  203.0  229.0
# 6   242  236.5  267.0  269  270  315.0  364  347.0  312  274.0  237.0  278.0
# 7   284  277.0  317.0  313  318  374.0  413  405.0  355  306.0  271.0  306.0
# 8   315  301.0  356.0  348  355  422.0  465  467.0  404  347.0  305.0  336.0
# 9   340  318.0  362.0  348  363  435.0  491  505.0  404  359.0  203.0  337.0
# 10  360  342.0  236.0  396  420  472.0  548  559.0  463  407.0  362.0  405.0
# ...

# %%
greater = air_df[air_df['Jan'] > air_df['Dec']]
greater
# Out:
#    Jan    Feb    Mar  Apr  May    Jun  Jul    Aug  Sep    Oct    Nov    Dec  \
# 9  340  318.0  362.0  348  363  435.0  491  505.0  404  359.0  203.0  337.0
#
#    Year
# 9  1958

# %% [markdown]
# # Ex - 7

# %%
temp_df = pd.read_csv('Data/nhtemp.csv')
temp_df
# Out:
#     Unnamed: 0  time  nhtemp
# 0            1  1912    49.9
# 1            2  1913    52.3
# 2            3  1914    49.4
# 3            4  1915    51.1
# 4            5  1916    49.4
# 5            6  1917    47.9
# 6            7  1918    49.8
# 7            8  1919    50.9
# 8            9  1920    49.3
# 9           10  1921    51.9
# 10          11  1922    50.8
# 11          12  1923    49.6
# 12          13  1924    49.3
# 13          14  1925    50.6
# 14          15  1926    48.4
# 15          16  1927    50.7
# 16          17  1928    50.9
# 17          18  1929    50.6
# 18          19  1930    51.5
# 19          20  1931    52.8
# 20          21  1932    51.8
# 21          22  1933    51.1
# 22          23  1934    49.8
# 23          24  1935    50.2
# 24          25  1936    50.4
# 25          26  1937    51.6
# 26          27  1938    51.8
# 27          28  1939    50.9
# 28          29  1940    48.8
# 29          30  1941    51.7
# 30          31  1942    51.0
# ...

# %%
temp_df = temp_df.iloc[:,1:]
temp_df
# Out:
#     time  nhtemp
# 0   1912    49.9
# 1   1913    52.3
# 2   1914    49.4
# 3   1915    51.1
# 4   1916    49.4
# 5   1917    47.9
# 6   1918    49.8
# 7   1919    50.9
# 8   1920    49.3
# 9   1921    51.9
# 10  1922    50.8
# 11  1923    49.6
# 12  1924    49.3
# 13  1925    50.6
# 14  1926    48.4
# 15  1927    50.7
# 16  1928    50.9
# 17  1929    50.6
# 18  1930    51.5
# 19  1931    52.8
# 20  1932    51.8
# 21  1933    51.1
# 22  1934    49.8
# 23  1935    50.2
# 24  1936    50.4
# 25  1937    51.6
# 26  1938    51.8
# 27  1939    50.9
# 28  1940    48.8
# 29  1941    51.7
# 30  1942    51.0
# 31  1943    50.6
# 32  1944    51.7
# 33  1945    51.5
# 34  1946    52.1
# 35  1947    51.3
# 36  1948    51.0
# 37  1949    54.0
# 38  1950    51.4
# 39  1951    52.7
# 40  1952    53.1
# 41  1953    54.6
# 42  1954    52.0
# 43  1955    52.0
# 44  1956    50.9
# 45  1957    52.6
# 46  1958    50.2
# 47  1959    52.6
# 48  1960    51.6
# 49  1961    51.9
# 50  1962    50.5
# ...

# %%
sns.distplot(temp_df["nhtemp"], hist = True, kde = False)
plt.title("Histogram of nhtemp")
plt.xlabel("nhtemp")
plt.ylabel("Frequency")
plt.show()
# Out:
# C:\Users\shakthi\AppData\Local\Temp\ipykernel_2168\2271935267.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(temp_df["nhtemp"], hist = True, kde = False)

# %%
temp_df.nhtemp.describe(percentiles=[0.25, 0.75])
# Out:
# count    60.000000
# mean     51.160000
# std       1.265608
# min      47.900000
# 25%      50.575000
# 50%      51.200000
# 75%      51.900000
# max      54.600000
# Name: nhtemp, dtype: float64

# %%
five_point_summary = temp_df['nhtemp'].describe()[['min', '25%', '50%', '75%', 'max']]
five_point_summary
# Out:
# min    47.900
# 25%    50.575
# 50%    51.200
# 75%    51.900
# max    54.600
# Name: nhtemp, dtype: float64

# %%
# Identify outliers based on the IQR method
Q1 = temp_df['nhtemp'].quantile(0.25)
Q3 = temp_df['nhtemp'].quantile(0.75)
IQR = Q3 - Q1

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# Detecting outliers
outliers = temp_df[(temp_df['nhtemp'] < lower_bound) | (temp_df['nhtemp'] > upper_bound)]
outlier_count = outliers.shape[0]
outlier_count
# Out:
# 4

# %%
outliers
# Out:
#     time  nhtemp
# 5   1917    47.9
# 14  1926    48.4
# 37  1949    54.0
# 41  1953    54.6

# %%
sns.boxplot(y=temp_df["nhtemp"])
plt.title("Boxplot of nhtemp")
plt.show()

# %%
# 4 outliers

# %% [markdown]
# # Ex - 8

# %%
# drug_df from ex 5

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='sideEffects', data=drug_df)
plt.title('Count of sideEffects')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='effectiveness', data=drug_df)
plt.title('Count of effectiveness')
plt.show()

# %% [markdown]
# # Ex - 9

# %%
temp_df = pd.read_csv('Data/nhtemp.csv')

# %%
# 1

temp_df.plot(x='time', y='nhtemp', kind='line', legend=False)

plt.title("Year vs Temperature")
plt.xlabel("Year")
plt.ylabel("Temperature")
plt.grid(True)
plt.show()

# %%
# 2
top_5_years = temp_df.sort_values(by='nhtemp', ascending=False).head(5)
print(top_5_years)

plt.plot(temp_df['time'], temp_df['nhtemp'], label='Temperature Trend')
plt.scatter(top_5_years['time'], top_5_years['nhtemp'], color='red', label='Top 5 Years', zorder=5)
plt.title("Top 5 Years with Highest Temperatures")
plt.xlabel("Year")
plt.ylabel("Temperature")
plt.legend()
plt.grid(True)
plt.show()
# Out:
#     Unnamed: 0  time  nhtemp
# 41          42  1953    54.6
# 37          38  1949    54.0
# 40          41  1952    53.1
# 59          60  1971    53.0
# 19          20  1931    52.8

# %%
plt.scatter(temp_df[temp_df['nhtemp'] > 52]['time'], temp_df[temp_df['nhtemp'] > 52]['nhtemp'], color='red', label='Temp > 52', alpha=0.7)
plt.scatter(temp_df[(temp_df['nhtemp'] <= 52) & (temp_df['nhtemp'] > 49)]['time'], temp_df[(temp_df['nhtemp'] <= 52) & (temp_df['nhtemp'] > 49)]['nhtemp'], color='green', label='49 < Temp ≤ 52', alpha=0.7)
plt.scatter(temp_df[temp_df['nhtemp'] <= 49]['time'], temp_df[temp_df['nhtemp'] <= 49]['nhtemp'], color='blue', label='Temp ≤ 49', alpha=0.7)

plt.title("Scatter Plot of Temperature Over Time")
plt.xlabel("Year")
plt.ylabel("Temperature")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Ex - 10

# %%
# 1
passenger_df = pd.read_csv('Data/AirPassengerscomplete.csv')
passenger_df
# Out:
#     Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# 0   112  118  132  129  121  135  148  148  136  119  104  118
# 1   115  126  141  135  125  149  170  170  158  133  114  140
# 2   145  150  178  163  172  178  199  199  184  162  146  166
# 3   171  180  193  181  183  218  230  242  209  191  172  194
# 4   196  196  236  235  229  243  264  272  237  211  180  201
# 5   204  188  235  227  234  264  302  293  259  229  203  229
# 6   242  233  267  269  270  315  364  347  312  274  237  278
# 7   284  277  317  313  318  374  413  405  355  306  271  306
# 8   315  301  356  348  355  422  465  467  404  347  305  336
# 9   340  318  362  348  363  435  491  505  404  359  310  337
# 10  360  342  406  396  420  472  548  559  463  407  362  405
# 11  417  391  419  461  472  535  622  606  508  461  390  432

# %%
passenger_df_melted = passenger_df.T
passenger_df_melted['Year'] = passenger_df_melted.index
passenger_df_melted = passenger_df_melted.melt(id_vars='Year', var_name='Month', value_name='Passengers')

plt.figure(figsize=(10, 6))
sns.boxplot(data=passenger_df_melted, x='Year', y='Passengers')
plt.xticks(rotation=45)
plt.title('Passenger Count Distribution by Year')
plt.xlabel('Year')
plt.ylabel('Passenger Count')
plt.tight_layout()
plt.show()

# %%
# 2
first_quartiles = passenger_df.T.quantile(0.25, axis=1)
lowest_first_quartile_year = first_quartiles.idxmin()
lowest_first_quartile_year
# Out:
# 'Jan'

# %%
# 3
third_quartiles = passenger_df.T.quantile(0.75, axis=1)
highest_third_quartile_year = third_quartiles.idxmax()
highest_third_quartile_year
# Out:
# 'Aug'

# %%
# 4
medians = passenger_df.T.median(axis=1)
is_median_increasing = medians.is_monotonic_increasing
is_median_increasing
# Out:
# False

# %%
# 5
plt.figure(figsize=(12, 6))
for year in passenger_df.columns:
    plt.plot(passenger_df.index, passenger_df[year], label=str(year))

plt.title('Passenger Count Over the Months for All Years')
plt.xlabel('Month')
plt.ylabel('Passenger Count')
plt.xticks(rotation=45)
plt.legend(title='Year', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Ex - 11

# %%
car_df = pd.read_csv('data/car.csv')
car_df
# Out:
#       vhigh vhigh.1      2   2.1  small   low  unacc
# 0     vhigh   vhigh      2     2  small   med  unacc
# 1     vhigh   vhigh      2     2  small  high  unacc
# 2     vhigh   vhigh      2     2    med   low  unacc
# 3     vhigh   vhigh      2     2    med   med  unacc
# 4     vhigh   vhigh      2     2    med  high  unacc
# ...     ...     ...    ...   ...    ...   ...    ...
# 1722    low     low  5more  more    med   med   good
# 1723    low     low  5more  more    med  high  vgood
# 1724    low     low  5more  more    big   low  unacc
# 1725    low     low  5more  more    big   med   good
# 1726    low     low  5more  more    big  high  vgood
#
# [1727 rows x 7 columns]

# %%
# 1
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for column in car_df.columns:
    car_df[column] = le.fit_transform(car_df[column])

sns.pairplot(car_df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
