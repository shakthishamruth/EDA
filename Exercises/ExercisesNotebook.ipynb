# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Ex - 2

# %%
drug_df = pd.read_csv('Data/drug.csv')
drug_df
# Out:
#                  urlDrugName  rating           effectiveness  \
# 0     2202         enalapril       4        Highly Effective
# 1     3117  ortho-tri-cyclen       1        Highly Effective
# 2     1146           ponstel      10        Highly Effective
# 3     3947          prilosec       3    Marginally Effective
# 4     1951            lyrica       2    Marginally Effective
# ...    ...               ...     ...                     ...
# 3102  1039           vyvanse      10        Highly Effective
# 3103  3281            zoloft       1             Ineffective
# 3104  1664           climara       2    Marginally Effective
# 3105  2621         trileptal       8  Considerably Effective
# 3106  2748          micardis       4    Moderately Effective
#
#                         sideEffects                               condition  \
# 0                 Mild Side Effects  management of congestive heart failure
# 1               Severe Side Effects                        birth prevention
# ...

# %% [markdown]
# # Ex - 3

# %%
feedback_df = pd.read_table('Data/feedback.txt', names = ['Reviews'])
feedback_df
# Out:
#                                               Reviews
# 0              The food for our event was delicious .
# 1    The food in the lounge was great and very fre...
# 2    As far as food, walk a few blocks toward Mich...
# 3    The Palm resturant in the hotel had some spec...
# 4    Took the charge of the minibar which we had u...
# 5    We never ate anything onsite so I can't vouch...
# 6    The Lobby bar does not serve food very late a...
# 7    In any case, I had allotted approximately $15...
# 8    But the presentation was awesome and the food...
# 9    The food was delicious and the view was fabul...
# 10   For self catering types, Bockwinkels is a wel...
# 11   Room service was extortionate though, very ve...
# 12   We also did the chicago food tasting tour whi...
# 13   So if you move around bottles in the fridge s...
# 14   We passed on the restaurants simply because t...
# 15   Also don't forget to go the &quot The River N...
# ...

# %%
feedback_df['Column_Id'] = pd.Series(range(0, 51))
feedback_df
# Out:
#                                               Reviews  Column_Id
# 0              The food for our event was delicious .          0
# 1    The food in the lounge was great and very fre...          1
# 2    As far as food, walk a few blocks toward Mich...          2
# 3    The Palm resturant in the hotel had some spec...          3
# 4    Took the charge of the minibar which we had u...          4
# 5    We never ate anything onsite so I can't vouch...          5
# 6    The Lobby bar does not serve food very late a...          6
# 7    In any case, I had allotted approximately $15...          7
# 8    But the presentation was awesome and the food...          8
# 9    The food was delicious and the view was fabul...          9
# 10   For self catering types, Bockwinkels is a wel...         10
# 11   Room service was extortionate though, very ve...         11
# 12   We also did the chicago food tasting tour whi...         12
# ...

# %% [markdown]
# # Ex - 4

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('Data/breakfast_menu.xml')
root = tree.getroot()
data = []
for food in root.findall("food"):
    item = {
        "name": food.find("name").text,
        "price": food.find("price").text,
        "description": food.find("description").text,
        "calories": int(food.find("calories").text)
    }
    data.append(item)

df = pd.DataFrame(data)

df
# Out:
#                           name  price  \
# 0              Belgian Waffles  $5.95
# 1   Strawberry Belgian Waffles  $7.95
# 2  Berry-Berry Belgian Waffles  $8.95
# 3                 French Toast  $4.50
# 4          Homestyle Breakfast  $6.95
#
#                                          description  calories
# 0   Two of our famous Belgian Waffles with plenty...       650
# 1   Light Belgian waffles covered with strawberri...       900
# 2   Light Belgian waffles covered with an assortm...       900
# 3   Thick slices made from our homemade sourdough...       600
# 4   Two eggs, bacon or sausage, toast, and our ev...       950

# %%
df.to_csv('Data/breakfast_menu.csv')

# %% [markdown]
# # Ex - 5

# %%
# drug_df from Ex-2

# %%
drug_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3107 entries, 0 to 3106
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0                      3107 non-null   int64
#  1   urlDrugName        3107 non-null   object
#  2   rating             3107 non-null   int64
#  3   effectiveness      3107 non-null   object
#  4   sideEffects        3107 non-null   object
#  5   condition          3106 non-null   object
#  6   benefitsReview     3089 non-null   object
#  7   sideEffectsReview  3032 non-null   object
#  8   commentsReview     3095 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 218.6+ KB

# %%
drug_df.shape[0]
# Out:
# 3107

# %%
drug_df.isna().sum()
# Out:
#                       0
# urlDrugName           0
# rating                0
# effectiveness         0
# sideEffects           0
# condition             1
# benefitsReview       18
# sideEffectsReview    75
# commentsReview       12
# dtype: int64

# %% [markdown]
# # Ex - 6

# %%
dataAir = pd.read_csv('Data/AirPassengers.csv')
first_half_df = dataAir.iloc[:,:6]
second_half_df = dataAir.iloc[:,6:]

# %%
first_half_df.head()
# Out:
#    Jan    Feb    Mar  Apr  May    Jun
# 0  112  118.0  132.0  129  121  135.0
# 1  115    NaN  141.0  135  125  149.0
# 2  145  150.0  178.0  163  172    NaN
# 3  171  180.0  193.0  181  183  218.0
# 4  196  196.0  236.0  235  229  243.0

# %%
second_half_df.head()
# Out:
#    Jul    Aug  Sep    Oct    Nov    Dec
# 0  148  148.0  136  119.0  104.0    NaN
# 1  170  170.0  158  133.0  114.0  140.0
# 2  199  199.0  184  162.0  146.0  166.0
# 3  230    NaN  209  191.0  172.0  194.0
# 4  264  272.0  237  211.0  180.0  201.0

# %%
air_df = first_half_df.merge(second_half_df, left_index=True, right_index=True, how='inner')
air_df
# Out:
#     Jan    Feb    Mar  Apr  May    Jun  Jul    Aug  Sep    Oct    Nov    Dec
# 0   112  118.0  132.0  129  121  135.0  148  148.0  136  119.0  104.0    NaN
# 1   115    NaN  141.0  135  125  149.0  170  170.0  158  133.0  114.0  140.0
# 2   145  150.0  178.0  163  172    NaN  199  199.0  184  162.0  146.0  166.0
# 3   171  180.0  193.0  181  183  218.0  230    NaN  209  191.0  172.0  194.0
# 4   196  196.0  236.0  235  229  243.0  264  272.0  237  211.0  180.0  201.0
# 5   204  188.0  235.0  227  234  264.0  302  293.0  259    NaN  203.0  229.0
# 6   242    NaN  267.0  269  270  315.0  364  347.0  312  274.0  237.0  278.0
# 7   284  277.0  317.0  313  318  374.0  413  405.0  355  306.0  271.0  306.0
# 8   315  301.0  356.0  348  355  422.0  465  467.0  404  347.0  305.0  336.0
# 9   340  318.0  362.0  348  363  435.0  491  505.0  404  359.0    NaN  337.0
# 10  360  342.0    NaN  396  420  472.0  548  559.0  463  407.0  362.0  405.0
# ...

# %%
air_df.isna().sum()
# Out:
# Jan    0
# Feb    2
# Mar    1
# Apr    0
# May    0
# Jun    1
# Jul    0
# Aug    1
# Sep    0
# Oct    1
# Nov    1
# Dec    1
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
df = air_df.loc[:,["Feb"]]
df[df.isna().any(axis=1)].index.tolist()
# Out:
# [1, 6]

# %%
air_df['Feb'] = air_df['Feb'].fillna(air_df['Feb'].median())
air_df['Mar'] = air_df['Mar'].fillna(air_df['Mar'].median())
air_df['Jun'] = air_df['Jun'].fillna(air_df['Jun'].median())
air_df['Aug'] = air_df['Aug'].fillna(air_df['Aug'].median())
air_df['Oct'] = air_df['Oct'].fillna(air_df['Oct'].median())
air_df['Nov'] = air_df['Nov'].fillna(air_df['Nov'].median())
air_df['Dec'] = air_df['Dec'].fillna(air_df['Dec'].median())
air_df
# Out:
#     Jan    Feb    Mar  Apr  May    Jun  Jul    Aug  Sep    Oct    Nov    Dec
# 0   112  118.0  132.0  129  121  135.0  148  148.0  136  119.0  104.0  278.0
# 1   115  236.5  141.0  135  125  149.0  170  170.0  158  133.0  114.0  140.0
# 2   145  150.0  178.0  163  172  315.0  199  199.0  184  162.0  146.0  166.0
# 3   171  180.0  193.0  181  183  218.0  230  347.0  209  191.0  172.0  194.0
# 4   196  196.0  236.0  235  229  243.0  264  272.0  237  211.0  180.0  201.0
# 5   204  188.0  235.0  227  234  264.0  302  293.0  259  274.0  203.0  229.0
# 6   242  236.5  267.0  269  270  315.0  364  347.0  312  274.0  237.0  278.0
# 7   284  277.0  317.0  313  318  374.0  413  405.0  355  306.0  271.0  306.0
# 8   315  301.0  356.0  348  355  422.0  465  467.0  404  347.0  305.0  336.0
# 9   340  318.0  362.0  348  363  435.0  491  505.0  404  359.0  203.0  337.0
# 10  360  342.0  236.0  396  420  472.0  548  559.0  463  407.0  362.0  405.0
# ...

# %%
air_df.isna().sum()
# Out:
# Jan    0
# Feb    0
# Mar    0
# Apr    0
# May    0
# Jun    0
# Jul    0
# Aug    0
# Sep    0
# Oct    0
# Nov    0
# Dec    0
# dtype: int64

# %%
air_df['Year'] = pd.Series(range(1949, 1961))
air_df
# Out:
#     Jan    Feb    Mar  Apr  May    Jun  Jul    Aug  Sep    Oct    Nov    Dec  \
# 0   112  118.0  132.0  129  121  135.0  148  148.0  136  119.0  104.0  278.0
# 1   115  236.5  141.0  135  125  149.0  170  170.0  158  133.0  114.0  140.0
# 2   145  150.0  178.0  163  172  315.0  199  199.0  184  162.0  146.0  166.0
# 3   171  180.0  193.0  181  183  218.0  230  347.0  209  191.0  172.0  194.0
# 4   196  196.0  236.0  235  229  243.0  264  272.0  237  211.0  180.0  201.0
# 5   204  188.0  235.0  227  234  264.0  302  293.0  259  274.0  203.0  229.0
# 6   242  236.5  267.0  269  270  315.0  364  347.0  312  274.0  237.0  278.0
# 7   284  277.0  317.0  313  318  374.0  413  405.0  355  306.0  271.0  306.0
# 8   315  301.0  356.0  348  355  422.0  465  467.0  404  347.0  305.0  336.0
# 9   340  318.0  362.0  348  363  435.0  491  505.0  404  359.0  203.0  337.0
# 10  360  342.0  236.0  396  420  472.0  548  559.0  463  407.0  362.0  405.0
# ...

# %%
greater = air_df[air_df['Jan'] > air_df['Dec']]
greater
# Out:
#    Jan    Feb    Mar  Apr  May    Jun  Jul    Aug  Sep    Oct    Nov    Dec  \
# 9  340  318.0  362.0  348  363  435.0  491  505.0  404  359.0  203.0  337.0
#
#    Year
# 9  1958
